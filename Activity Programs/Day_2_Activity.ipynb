# %% [markdown]
# <a href="https://colab.research.google.com/github/LohithVarun/DSA0615-DataHandlingAndVisualization/blob/main/Activity%20Programs/Day_2_Activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DAY 2

# %% [markdown]
# 1) Vertical Bar Chart: Compares sales figures for each product category across different months. Each product category has its own set of bars, with different colors representing different months.
#
# Horizontal Bar Chart: Similar to the vertical bar chart, but with categories listed along the y-axis and sales figures along the x-axis. This orientation can be useful for displaying longer category names.
#
# Grouped Bar Chart: Compares sales figures for each product category across different months side by side. Each pair of bars represents sales for a specific category in January and February.
#
# Stacked Bar Chart: Shows the total sales for each month, with each bar divided into segments representing different product categories. This allows viewers to see the contribution of each category to the total sales for each month
#
# ---

# %%
library(ggplot2)

df <- data.frame(Month = c("January", "February", "March", "April", "May", "June", "July", "Aug", "Sep", "Oct", "Nov", "Dec"),
                 Category_A = c(500, 600, 700, 500, 800, 800, 500, 700, 500, 800, 500, 600),
                 Category_B = c(700, 800, 500, 600, 400, 400, 700, 500, 600, 400, 700, 800),
                 Category_C = c(600, 700, 600, 800, 300, 300, 600, 600, 800, 300, 600, 700))

ggplot(df, aes(x = Month, y = Category_A, fill = Month)) + geom_bar(stat = "identity") + labs(x = "Month", y = "Sales", fill = "Month")

ggplot(df, aes(x = Category_A, y = Month, fill = Month)) + geom_bar(stat = "identity") + labs(x = "Sales", y = "Month", fill = "Month")

ggplot(df, aes(x = Month, y = Category_A, fill = interaction(Month, Category_A))) + geom_bar(stat = "identity") + labs(x = "Month", y = "Sales", fill = "Month")

ggplot(df, aes(x = Month, y = Category_A, fill = factor(interaction(Month, Category_A)))) + geom_bar(stat = "identity", position = "fill") + labs(x = "Month", y = "Sales", fill = "Category")
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
